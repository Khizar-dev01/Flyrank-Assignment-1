# %% [markdown]
# <a href="https://colab.research.google.com/github/Khizar-dev01/Flyrank-Assignment-1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Khizar-dev01/Flyrank-Assignment-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/Khizar-dev01/Flyrank-Assignment-1.git
# %cd Flyrank-Assignment-1
# Out:
# Cloning into 'Flyrank-Assignment-1'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 123 (delta 39), reused 99 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# /content/Flyrank-Assignment-1/Flyrank-Assignment-1

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.columns.tolist())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My Lane
#
# I chose the Content Refresh Prioritization lane because many websites contain thousands of pages, making it difficult to decide which ones should be updated first. Using historical search performance and content-related metrics, I want to identify pages that are likely declining in performance so content teams can prioritize updates. This project focuses on supporting decisions rather than replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# Can we identify content pages that should be refreshed based on historical search performance and content quality signals?
#
# **Unit of analysis:** One content page.
#
# **Output:** A priority score or prediction indicating whether a page should be refreshed.
#
# **Decision:** Decide which pages should be updated first.
#
# **Action:** The SEO or content team refreshes the recommended pages.
#
# **Cost of a wrong recommendation:** Recommending the wrong pages wastes time and resources, while missing important declining pages could reduce search traffic and business opportunities.
#
# Machine learning helps by finding patterns across many content metrics that would be difficult to evaluate manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Unique clients:", df["client_id"].nunique())
print("Average CTR:", round(df["ctr"].mean(), 2))
print("Average Position:", round(df["avg_position"].mean(), 2))
print("Average Content Age:", round(df["content_age_days"].mean(), 0))
print("Pages trending down:",
      (df["trend_direction"]=="down").sum())
# Out:
# Total pages: 30000
# Unique clients: 32
# Average CTR: 0.51
# Average Position: 16.34
# Average Content Age: 256.0
# Pages trending down: 16262

# %% [markdown]
# ### Quick Look at the Data
#
# The starter dataset contains **30,000 content pages** collected from **(your unique client count)** clients.
#
# The average click-through rate (CTR) is approximately **(your value)**.
#
# The average content age is approximately **(your value)** days.
#
# These numbers show that the dataset contains enough variety to study which pages are most likely to benefit from content refreshes.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What I Can and Can't Claim
#
# This project can identify patterns that may help prioritize content refresh decisions.
#
# The model does not prove that refreshing a page will definitely improve its search performance. It provides decision support based on historical data rather than causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
